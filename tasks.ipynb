# %% [markdown]
# # Tasks

# %% [markdown]
# # Task 1: Source the Data Set

# %% [markdown]
# ### Objective Import the Iris data set from the sklearn.datasets module.

# %% [markdown]
# ### 1. Execute import function

# %%
from sklearn.datasets import load_iris

iris = load_iris()

print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
print("First 5 data rows:\n", iris.data[:5])
print("First 5 targets:", iris.target[:5])

# %% [markdown]
# ### 2. load_iris() contains the dataset of Iris flowers — including all the measurements (data), the species labels (target), and some helpful info (feature names, target names, description).

# %% [markdown]
# # Task 2: Explore the Data Structure

# %% [markdown]
# ### Objective
# ## 1. Print and explain the shape of the data set, the first and last 5 rows of the data, the feature names, and the target classes.

# %%
from sklearn.datasets import load_iris

iris = load_iris()

print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
print("First 5 data rows:\n", iris.data[:5])
print("First 5 targets:", iris.target[:5])
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']
# First 5 data rows:
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# First 5 targets: [0 0 0 0 0]

# %% [markdown]
# ## Summary of Data
#
# ### 1. The actual data (flower measurements),
#
# ### 2. The labels (which species each flower belongs to),
#
# ### 3. The names of the features and labels,
#
# ### 4. And a nice description to understand the dataset

# %% [markdown]
# ## Task 3: Summarize the Data

# %% [markdown]
# ## Objective
#
# ## For each feature in the dataset, calculate and display:
#
# ### 1. mean
# ### 2. minimum
# ### 3. maximum
# ### 4. standard deviation
# ### 5. median

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# Load the dataset
iris = load_iris()

# Convert to a DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Describe each feature
print("Feature Statistics:\n")

for column in df.columns:
    print(f"Feature: {column}")
    print(f"  Mean: {df[column].mean():.2f}")
    print(f"  Min: {df[column].min():.2f}")
    print(f"  Max: {df[column].max():.2f}")
    print(f"  Std Dev: {df[column].std():.2f}")
    print(f"  Median: {df[column].median():.2f}")
    print()
# Out:
# Feature Statistics:
#
# Feature: sepal length (cm)
#   Mean: 5.84
#   Min: 4.30
#   Max: 7.90
#   Std Dev: 0.83
#   Median: 5.80
#
# Feature: sepal width (cm)
#   Mean: 3.06
#   Min: 2.00
#   Max: 4.40
#   Std Dev: 0.44
#   Median: 3.00
#
# Feature: petal length (cm)
#   Mean: 3.76
#   Min: 1.00
#   Max: 6.90
#   Std Dev: 1.77
#   Median: 4.35
#
# Feature: petal width (cm)
#   Mean: 1.20
#   Min: 0.10
#   Max: 2.50
#   Std Dev: 0.76
#   Median: 1.30

# %% [markdown]
# ## Task 4: Visualize Features

# %% [markdown]
# ## Objectives:
# ## Plot histograms for each feature using matplotlib.
# ## Add appropriate titles and axis labels.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Load the dataset and create a DataFrame
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Set up the figure and axes (2x2 grid for 4 features)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()  # Flatten 2D array of axes to 1D

# Plot a histogram for each feature
for i, column in enumerate(df.columns):
    axes[i].hist(df[column], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(f"Histogram of {column}")
    axes[i].set_xlabel(column)
    axes[i].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 5: Investigate Relationships
#
# ## Objective:
# ### 1. Choose any two features from the data set and create a scatter plot of them.
# ### 2. Color-code the three different classes of the scatter plot points

# %% [markdown]
# ### Sepal width vs Petal width

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Load dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# Features that are not commonly plotted together
x_feature = 'sepal width (cm)'
y_feature = 'petal width (cm)'

# Plot
plt.figure(figsize=(8, 6))
for species in iris.target_names:
    subset = df[df['species'] == species]
    plt.scatter(subset[x_feature], subset[y_feature], label=species)

plt.title('Sepal Width vs Petal Width by Species')
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 6: Analyze Relationship
# ### Objective:
# ### 1.Use numpy.polyfit to add a regression line to the scatter plot from Task 5

# %% [markdown]
# ### Scatter Plot with Regression Lines (Using numpy.polyfit)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# Load and prepare the data
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# Select features
x_feature = 'sepal width (cm)'
y_feature = 'petal width (cm)'

plt.figure(figsize=(8, 6))

# Plot each species separately
for species in iris.target_names:
    subset = df[df['species'] == species]
    x = subset[x_feature]
    y = subset[y_feature]
    
    # Scatter plot
    plt.scatter(x, y, label=species)
    
    # Linear regression line using numpy.polyfit
    coeffs = np.polyfit(x, y, 1)  # degree 1 for linear
    poly_eqn = np.poly1d(coeffs)
    plt.plot(x, poly_eqn(x), linestyle='--', label=f'{species} fit')

# Plot formatting
plt.title('Sepal Width vs Petal Width with Regression Lines')
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 7: Analyze Class Distributions
# #### Objective:
# ### 1.Create box-plots of the petal lengths for each of the three classes.

# %% [markdown]
# ## Task 8: Compute Correlations

# %% [markdown]
# ## Task 9: Fit a Simple Linear Regression

# %% [markdown]
# ## Task 10: Too Many Features
